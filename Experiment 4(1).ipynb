# %%
import pandas as pd
import numpy as np
labels=['a','b','c']
list1=[10,20,30]
a=np.array([10,20,30])
d={'a':10,'b':20,'c':30}
pd.Series(data=list1)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(data=list1,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(list1,labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(a)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(a,labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
ser1=pd.Series([10,20,30,40],index=['apple','orange','mango','cherry'])
ser2=pd.Series([10,20,30,40],index=['apple','orange','banana','kiwi'])
ser1+ser2
# Out:
# apple     20.0
# banana     NaN
# cherry     NaN
# kiwi       NaN
# mango      NaN
# orange    40.0
# dtype: float64

# %%
ser1['mango']
# Out:
# np.int64(30)

# %%
from  numpy.random import randn
np.random.seed(101)
df=pd.DataFrame(randn(5,4),index='A B C D E'.split(),columns='W X Y Z'.split())
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509
